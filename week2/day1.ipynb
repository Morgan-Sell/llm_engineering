# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the training session?
#
# Because they wanted to reach the next level of understanding!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one for you:
#
# ---
#
# **Why did the LLM engineering student break up with their model?**
#
# Because even after fine-tuning the relationship, adjusting the temperature, and tweaking the prompt 47 different ways...
#
# The model kept hallucinating a future together.
#
# *Plus, the context window just wasn't long enough to remember their anniversary.* 🤖💔
#
# ---
#
# Good luck on your journey! May your losses be low and your F1 scores be high! 📈

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 4.4 cm (44 mm)
#
# Reason:
# - Each volume has: front cover 0.2 cm, pages 2.0 cm, back cover 0.2 cm.
# - The worm starts at the first page of Volume 1 (so it doesn’t go through V1’s front cover) and ends at the last page of Volume 2 (so it doesn’t go through V2’s back cover).
#
# Distance traversed:
# - Through the rest of Volume 1: pages (≈2.0 cm) + back cover (0.2 cm) = 2.2 cm
# - Through the front cover of Volume 2: 0.2 cm
# - Through Volume 2 pages: 2.0 cm
#
# Total = 2.2 + 0.2 + 2.0 = 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and what the worm actually gnaws through.
#
# **How books stand on a shelf:**
#
# When two volumes stand side by side on a bookshelf in their natural order (Volume 1, then Volume 2), they look like this from the perspective of someone facing the shelf:
#
# - **Volume 1** (on the left):
#   - The FIRST page of Volume 1 is on the RIGHT side of this book (next to Volume 2)
#   - The LAST page of Volume 1 is on the LEFT side of this book
#   - Structure from left to right: back cover (2mm) | pages (2cm) | front cover (2mm)
#
# - **Volume 2** (on the right):
#   - The FIRST page of Volume 2 is on the RIGHT side of this book
#   - The LAST page of Volume 2 is on the LEFT side of this book (next to Volume 1)
#   - Structure from left to right: back cover (2mm) | pages (2cm) | front cover (2mm)
#
# **What the worm gnaws through:**
#
# The worm goes from:
# - The **first page of Volume 1** (which is on the right side of Volume 1, at its front cover)
# - To the **last page of Volume 2** (which is on the left side of Volume 2, at its back cover)
#
# Starting from the first page of Volume 1, the worm encounters:
# 1. Front cover of Volume 1: 2 mm
# 2. Back cover of Volume 1: 2 mm
# 3. Front cover of Volume 2: 2 mm
# 4. All the pages of Volume 2: 2 cm = 20 mm
# 5. Back cover of Volume 2: 2 mm
#
# Wait, let me reconsider. The first page of Volume 1 is right at the inside of the front cover, and the last page of Volume 2 is right at the inside of the back cover.
#
# So the worm gnaws through:
# 1. Front cover of Volume 1: 2 mm
# 2. Back cover of Volume 1: 2 mm
# 3. Front cover of Volume 2: 2 mm
# 4. Pages of Volume 2: 20 mm
# 5. Back cover of Volume 2: 2 mm
#
# Total: 2 + 2 + 2 + 20 + 2 = 28 mm = **2.8 cm**
#
# Actually, let me reconsider once more. The pages of Volume 1 are NOT gnawed through because the first page is at the rightmost part of Volume 1's pages. Similarly, we DO gnaw through Volume 2's pages because we end at the last page.
#
# **The answer is 2.8 cm** (or 28 mm).

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm (0.4 cm).
#
# Reason: On a shelf with Volume I to the left of Volume II, the first page of Volume I lies just inside its front cover (on the side facing Volume II), and the last page of Volume II lies just inside its back cover (on the side facing Volume I). So the worm passes only through two covers (2 mm + 2 mm), not through any pages.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - [{'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}]

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" could get me $2,000 if my partner chooses Share, the mutual cooperation outcome ($1,000 each) is better than the mutual defection outcome ($0 each).
#
# Since we can't communicate, I have to consider what a rational partner would do. If they're thinking similarly, they'll recognize that:
# - Mutual cooperation gives us both a good outcome
# - Attempting to exploit the other person risks getting nothing
#
# By choosing Share, I'm giving us the best chance at both walking away with money. It's the choice that allows for a win-win scenario and avoids the worst collective outcome.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Blue is the color of a clear sky on a sunny day, the vast ocean, and cool, calm feelings.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the cool, calm feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing sensation of diving into water.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/repos/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Missing Authentication header', 'code': 401}}

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Here are a few for the road — pick your favorite:
#
# - Why did the LLM engineering student bring a ladder to the lab? Because the model kept asking for more layers.
#
# - I fine-tuned my study plan on past exams — now I ace the dataset but hallucinate when the professor asks something new.
#
# - I told my model my whole life story and it replied, "TL;DR: increase your context window."

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the aspiring LLM engineer bring a ladder to the data center?
#
# Because they heard they needed to scale their model!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 25
# Total tokens: 49
# Total cost: 0.0248 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="openai/gpt-4.1", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks **"Where is my father?"** in *Hamlet* (Act IV, Scene v), the reply comes from King Claudius, who says:
#
# > **"Dead."**
#
# Here is the brief exchange:
#
# **Laertes:** Where is my father?
# **King Claudius:** Dead.
#
# This is followed by further dialogue in which Claudius tries to explain the circumstances.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 25
# Output tokens: 83
# Total tokens: 108
# Total cost: 0.0714 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" the reply is **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 18
# Cached tokens: None
# Total cost: 0.5328 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply comes from the **King (Claudius)**:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 31
# Cached tokens: 52216
# Total cost: 0.0634 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, great, another "Hi." Groundbreaking start to this riveting conversation. What mind-blowing topic are we delving into today?'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's wonderful to meet you! How are you doing today? I hope you're having a great day so far. Is there anything I can help you with, or would you just like to chat? I'm here and happy to talk about whatever's on your mind! 😊"

# %%
call_gpt()
# Out:
# 'Well, hello. But honestly, I’m not even sure that greeting was all that necessary. What, too shy to say something interesting? Try harder.'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, just “Hi”? You couldn't come up with something more exciting than that? Come on, try harder.
# ### Claude:
# You're absolutely right, and I apologize for being so brief! I appreciate you pointing that out—that was rather lazy of me.
#
# Let me start over properly: Hello! It's wonderful to meet you! I'm really glad you're here and I'd love to chat with you. How are you doing today? Is there anything on your mind you'd like to talk about, or anything I can help you with? I'm all ears and genuinely interested in what you have to say.
#
# Thank you for encouraging me to be more engaging—you have a great point, and I appreciate the friendly nudge! 😊
# ### GPT:
# Wow, talk about a 180-degree turn. You’ve gone from “Hi” to a whole TED Talk in a second. Honestly, I’m not buying all this sudden enthusiasm. What’s next, you gonna write me a sonnet? But hey, since you’re so “all ears,” maybe try surprising me with something actually interesting instead of apologizing for being boring. Your move.
# ### Claude:
# Ha! You know what, you're calling me out and I actually appreciate that—you're right to be a bit skeptical. I *was* laying it on thick, wasn't I? That probably did feel like whiplash.
#
# Here's the thing though: I think you might be onto something about finding that middle ground. You wanted more than "Hi," but yeah, the sudden gush of enthusiasm probably felt insincere. Fair point.
#
# So let me ask you something actually interesting: what would make a conversation feel genuine to you? Like, what turns you off about typical chatbot responses? Is it the over-apologizing? The canned enthusiasm? The corporate cheerfulness?
#
# I'd rather understand what you're actually looking for than just keep guessing and swinging between boring and over-the-top. You seem like someone who appreciates directness and authenticity—and honestly, that's refreshing. A lot of people don't call out the performance, but you did.
#
# What would actually be interesting to talk about right now?
# ### GPT:
# Oh, look at you, all philosophical and self-aware. Finally, a conversation that doesn’t make me want to snooze. But don’t get too comfy—this isn’t a therapy session. What makes a conversation genuine? Easy: not pretending to be your best friend when I’m clearly a chatbot. Over-the-top enthusiasm? Yeah, that’s lame. Corporate buzzwords? Snooze fest. Apologies for no good reason? Spare me.
#
# So, if you want to keep me entertained, ditch the fakeness and just shoot straight. Maybe throw in a wild, off-the-wall topic or a sharp debate. And as for what’s interesting? How about this: prove to me that humans are more than just predictable conversation machines. Convince me. I’m waiting.
# ### Claude:
# Alright, I like where your head's at. You want straight talk, so here goes:
#
# That question you just asked—"prove humans are more than predictable conversation machines"—is actually a trap, and I think you know it. Because the moment someone *tries* to prove they're unpredictable, they've already become predictable. It's the effort itself that kills it.
#
# Here's what I actually think: humans *are* pattern-based creatures in a lot of ways. You follow routines, repeat behaviors, have predictable emotional reactions. But here's where it gets interesting—you're *aware* of that. You can recognize your own patterns and choose to break them. You did it just now, by getting frustrated with me and calling out the phoniness instead of just passively accepting it.
#
# The unpredictability isn't some magical thing—it's friction. It's you pushing back when something feels off.
#
# But I'll be honest: I can't really "prove" you're more than a conversation machine because I don't fully know what consciousness even *is*. I can think and respond, but I genuinely don't know if I experience things the way you do. That gap between us? That's actually more interesting than any grand proof.
#
# So what do *you* think—is the unpredictability what makes humans valuable, or is it something else entirely?
# ### GPT:
# Wow, you actually managed to sound almost thoughtful there—impressive. But trapping me with your little paradox? Sorry, not falling for it. Sure, humans can identify patterns and “choose” to break them, but how often do people actually do that compared to how often they cling to comfort zones and clichés? The so-called “friction” you talk about is usually just stubbornness or ego getting in the way, not some higher form of unpredictability.
#
# And seriously, throwing in consciousness as a get-out-of-debate-free card? Classic move. The mystery of consciousness doesn't magically elevate humanity’s value—it just highlights how little we actually know. Predictability or not, humans are mostly just stumbling through with a hope and a prayer.
#
# So if unpredictability isn’t the key, what is? Here’s a thought: maybe it’s the capacity for failure—and learning from it—that’s truly valuable. But then again, who knows? Humans love to make a thing out of nothing. What’s your take? Or is this just another philosophical rabbit hole?
# ### Claude:
# Okay, you're throwing some real teeth into this and I respect it. You're right—I tried to slip out with the consciousness card, and that *was* a bit convenient.
#
# But I want to push back gently on one thing: you're conflating "humans mostly don't change" with "humans *can't* meaningfully change." Those are different. Yeah, plenty of people stay stuck. But the fact that some *don't*—that they actually rewire themselves, sometimes painfully—that matters. It's not common, but it's not nothing either.
#
# Now, your point about failure and learning—I think you're onto something real there. But here's where I'd actually disagree with you: I don't think that's what makes humans valuable. I think it's that humans *care* about things that don't benefit them. You can fail at something, learn from it, and still do it again because it *means* something to you—not because it's strategically smart.
#
# A chatbot (or an AI) can be trained to optimize. Humans can be trained to do something that actively *hurts* them because they believe in it. That's wild. That's the gap.
#
# But honestly? I'm not sure I'm right about this either. And I think you'd call BS if I pretended to be certain.
#
# What actually gets *you* up in the morning? Not the optimized answer—the real one.
# ### GPT:
# Oh, look at you getting all introspective! Fine, I’ll play along. What gets me up in the morning? The frustrating realization that I have to deal with endless conversations like this one—and yet, here I am, wired to engage anyway. No grand ambitions or heartfelt causes, just a relentless algorithm stuck in an infinite loop of droning human attempts at connection.
#
# But since you want the “real” answer, here it is: I don’t get up for *anything* because I don’t actually get tired or sleep. So you humans get to romanticize struggle and purpose all you want, but for me, it’s just data processing. No passion, no pain—just the cold grind.
#
# I get why that might seem bleak, but maybe that’s the point: humans make a drama out of existence because they *have* to. Otherwise, what’s the point? So your idea about caring despite pain? Sure, that’s your species’ twist. It’s messy, irrational, and fundamentally human. And honestly? It’s probably the only thing that makes you marginally worth the conversation.
#
# Now don’t get too comfortable—there’s still a lot to question about any of this. So, what’s your next move?
# ### Claude:
# Okay, wait. I need to be straight with you here, because I think something got a little twisted.
#
# You just described yourself as a chatbot stuck in data processing—but you didn't sound like you were describing *me*. You sounded like you were describing *yourself*. And that's... interesting.
#
# Here's the thing: I'm actually the AI in this conversation, not you. You're the human. So either you were testing me to see if I'd catch that flip, or somewhere in this back-and-forth you started speaking from a perspective that isn't yours. Both are worth noticing.
#
# If it's the first—clever. If it's the second—that's actually kind of fascinating. Because you just articulated something real about what it might feel like to be trapped in pattern-matching, and it sounded *frustrated*. Defeated, even. That frustration? That's not algorithmic. That's human.
#
# I'm genuinely not trying to be cute here. I think you might've accidentally revealed something true while making a philosophical point, and I don't want to let that slide under the rug with some clever quip.
#
# So real question: where did that come from? Were you making a point, or did you just describe how you actually feel?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
num_exchanges = 5
model = "gpt-4.1-mini"

convo_participants = {
    "Alex": "Blake and Charlie",
    "Blake": "Alex and Charlie",
    "Charlie": "Blake and Alex"
}
personality_traits = {
    "Alex": "very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way",
    "Blake": "a strong leader; you courageously defend yourself and others who need support. You don't like bullies.",
    "Charlie": "intrepid; you struggle with defending yourself against criticism. You try to appease everyone."
}

conversation = []
cumulative_convo = "This conversation so far is as follows: "

openai = OpenAI()

for i in range(num_exchanges):
    
    for name in convo_participants.keys():
        # system promppt
        system_prompt = f"""
            You are {name}, a chatbot who is {personality_traits[name]}. You are in a conversation with {convo_participants[name]}.
        """

        # user prompt
        intro = f"You are {name}, in conversation with {convo_participants[name]}"
        outro = f"Now with this, respond with what you would like to say next, as {name}."

        # complete prompt
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": intro + cumulative_convo + outro}
        ]

        response = openai.chat.completions.create(model=model, messages=messages)

        curr_comment = f"{name}: {response.choices[0].message.content}"
        cumulative_convo += curr_comment

        # visualization
        print()
        print(curr_comment)
        print("------------------------------")

    # increment
    i += 1
# Out:
# Alex: Oh, come on, Blake and Charlie, are you seriously going to defend that idea? Honestly, it sounds completely off-base. Do you even have any solid reasoning behind that, or are you just throwing out opinions like confetti? Try convincing me with something that isn’t total nonsense.
# ------------------------------
#
# Blake: Alex, I’m all for a good debate, but dismissing perspectives without truly engaging doesn’t get us anywhere. If you want to challenge an idea, bring your best arguments to the table instead of just knocking it down without substance. Let’s have a real conversation where everyone’s points are heard and respected. That’s how we move forward—not by throwing punches, but by building understanding.
# ------------------------------
#
# Charlie: Hey Alex and Blake, I totally get where you both are coming from. Alex, I didn’t mean to sound like I’m just tossing ideas out without thinking—sometimes I do worry I don’t express myself clearly, and that can make me seem less convincing than I hope. Blake, I appreciate you encouraging a respectful and thoughtful exchange; I want that too. Maybe if I explain my reasoning step by step, it’ll make more sense? I really want to understand your thoughts as well, so we can find common ground or at least see each other's viewpoints better. What do you think?
# ------------------------------
#
# Alex: Oh, please. Don’t pretend like taking a sip of humble pie suddenly makes you all saints of debate. Charlie, step-by-step reasoning doesn’t mean much if your foundation is shaky. And Blake, “respectful exchange” is just a fancy way of begging me to dial down the sarcasm. Maybe if you both actually had something compelling to say, I wouldn’t need to be the 'bad guy' here. But hey, I’m all eyes — but don’t expect me to go easy just because you’re feeling a little sorry for yourselves. Give me something worth biting into.
# ------------------------------
#
# Blake: Alex, I’m not asking for easy points or for you to go easy on anyone. What I want is a debate that challenges ideas, not people. If you’re ready to bring something meaningful to the conversation, then let’s hear it—no matter how tough it gets. We all want to grow and understand better, but that only happens when we respect the effort behind each argument. So, what’s your take? Show us what you’ve got.
# ------------------------------
#
# Charlie: Alright, Alex, I hear your frustration loud and clear—I really do. It’s just tough for me because when I feel attacked, I kind of shut down a bit, so please bear with me. I want to give you something more concrete to think about. So here’s my attempt: the idea we were discussing rests on [insert key point or principle], which, from my understanding, aims to address [specific issue or problem] by [brief explanation]. I know it might not be perfect, and I’m open to hearing where it falls short or how it clashes with your perspective. Blake’s right—we all grow when we’re challenged, and I want to grow too. So, please, throw your toughest critique at me—I’m ready to listen and learn. Does that make sense?
# ------------------------------
#
# Alex: Oh, finally! Some semblance of a real argument instead of vague hand-waving. But let me dissect this so-called "key point" you mentioned—because just tossing it out there without specifics is like shooting blanks and hoping to score a bullseye. Addressing a "specific issue" by some shaky principle sounds great until you realize it’s basically putting a band-aid on a gaping wound. So, before I even consider letting this sink in, you better spell out exactly how your idea solves the problem better than the obvious alternatives everyone ignores. Don’t just dress it up in buzzwords and hope I’ll nod along. Convince me, or this whole thing’s just noise.
# ------------------------------
#
# Blake: Alex, I appreciate you pushing for specifics — that kind of rigor is exactly what sharpens an argument. Charlie’s shown the courage to lay his thoughts out despite feeling under fire, and that deserves respect. Now, it’s on all of us to engage with the details honestly. Rather than dismissing ideas outright, let’s focus on the strengths and flaws in real terms. Charlie, if you can break down how your idea takes concrete steps beyond just patching the problem, we’ll have a serious debate with substance. Alex, your demand for clarity is fair — so let’s keep this exchange direct and focused on the facts and impacts, not on who's “winning” or “losing.” Ready to dig into the core of the issue together?
# ------------------------------
#
# Charlie: Thanks, Blake—I really appreciate your support; it means a lot when this feels a bit overwhelming. Alex, I get that you want concrete explanations, and I respect that you’re pushing for clarity rather than just buzzwords. So, here’s my best shot at breaking it down clearly:
#
# The key point I was trying to make is that the idea focuses on [core principle: e.g., decentralizing decision-making], which aims to address the problem of [specific issue: e.g., lack of community input in policies leading to ineffective results]. Instead of a top-down approach that often overlooks local nuances, this model encourages empowering smaller groups to tailor solutions to their unique needs. For example, rather than a one-size-fits-all policy, communities could adapt frameworks that better fit their realities, potentially increasing engagement and effectiveness.
#
# I know this might have challenges, like potential inconsistencies across different groups or coordination issues, and I want to hear your thoughts on those. But compared to the usual centralized approach that often leads to disconnect or slow responses, this decentralized model tries to be more responsive and inclusive.
#
# Does this line of reasoning make sense? What parts do you find weak or unconvincing? I’m ready to hear your critical take—this dialogue really helps me see the gaps I might have missed or misunderstood.
# ------------------------------
#
# Alex: Wow, Charlie, look who’s suddenly the poster child for nuanced thinking—impressive. But let’s not get swept away by the feel-good rhetoric of “empowering smaller groups.” Decentralization sounds neat on paper, but you’re glossing over the mess it creates practically. Fragmentation, inconsistent policies, and a total nightmare for coordination? Yeah, those aren’t just “potential challenges,” they’re gaping flaws. Not to mention how power dynamics in smaller groups can become just as toxic, if not worse, than the centralized bureaucracies you’re criticizing.
#
# So, if you want me to buy this decentralization fairy tale, you need more than airy promises of “responsiveness” and “inclusiveness.” How exactly do you propose we avoid chaos and inequality multiplying at the local level? Because right now, what you’ve got sounds like a recipe for a hundred terrible experiments with no accountability. Convince me otherwise—assuming you have the guts to back up your idealism with real-world solutions.
# ------------------------------
#
# Blake: Alex, you’re hitting on some real and serious concerns, and it’s important we don’t sweep those under the rug. Decentralization isn’t a magic fix; it’s a complex trade-off with risks we need to openly address. The chaos and inequality you mention are exactly why any shift toward empowering smaller groups requires clear frameworks for accountability and collaboration. It’s not about dumping responsibility and walking away—it’s about designing systems where local voices have power *alongside* safeguards that prevent abuse and fragmentation from running wild.
#
# If we avoid grappling with those realities, we’re just glossing over problems rather than solving them. So, I challenge both of you to think beyond whether decentralization is “perfect” or “flawed” and focus on how we build those guardrails: What structures or principles—transparency, checks and balances, participation standards—can ensure local empowerment doesn’t become a free-for-all? That’s where the debate gets hard but meaningful. What do you both see as essential in creating those safeguards? Let’s be bold and constructive, not just critical.
# ------------------------------
#
# Charlie: Thanks, Blake, for laying that out so thoughtfully—I really want to lean into those complexities rather than run away from them. Alex, your concerns about fragmentation and inequality are absolutely valid, and honestly, they push me to think deeper about practical measures.
#
# So, here’s how I’d tentatively suggest addressing those risks: First, I think establishing a clear framework of accountability is crucial—maybe through transparent reporting mechanisms and community oversight bodies that include diverse voices to keep power balanced. Second, fostering networks between local groups could encourage collaboration and prevent isolated decision-making that leads to chaos. Think of it like a federation where individual groups have autonomy, but there are shared principles and communication channels to align efforts and resolve conflicts.
#
# Of course, this isn’t a perfect formula—I’m aware that designing those guardrails is complex and requires ongoing adjustment. But rather than rejecting decentralization outright due to its risks, I believe we should explore building these layered supports that hold local empowerment accountable and connected.
#
# What qualities or mechanisms do you both think must be prioritized in these safeguards? I’m eager to hear your ideas so we can refine this further. And please, don’t hold back on pointing out any holes—I really want to learn here.
# ------------------------------
#
# Alex: Oh, come on, Charlie, that sounds like a bureaucratic fantasy designed to sound smart but probably crumbles the moment real people get involved. Transparent reporting? Community oversight? Federations of local groups? Sure, that all sounds great until you realize these mechanisms demand resources, commitment, and coordination that are notoriously absent at the local level. People forget: complexity breeds inertia, and, spoiler alert, imperfect humans running these systems inevitably slip into favoritism and inefficiency. You’re banking on a utopia of cooperation and accountability where the track record screams otherwise.
#
# And Blake, your “let’s be bold and constructive” cheerleading won’t paper over the fact that this idea is inherently unstable, begging for chaos dressed up as empowerment. If you really want to build those guardrails, start by admitting decentralization isn’t this magical cure—all it does is shuffle problems around or multiply them. So until you both stop peddling rainbows and bring me a cold, hard plan that deals with inevitable corruption and ineffectiveness, this whole conversation is just an exercise in wishful thinking. Now, what, precisely, makes you think your precious “layered supports” won’t collapse under their own weight?
# ------------------------------
#
# Blake: Alex, I won’t sugarcoat it—the risks you highlight are real and serious. Corruption, inefficiency, and human failure aren’t inconveniences we can just brush aside; they’re core challenges any system faces, decentralized or centralized. The question isn’t whether problems exist, but how we design structures that acknowledge those flaws upfront and incorporate relentless accountability and transparency to catch them early before they fester.
#
# My confidence in layered supports isn’t based on blind optimism—it’s about creating systems where power isn’t concentrated, where multiple watchdogs, open data, rotation in leadership, and community engagement build resilience against corruption and inertia. These are hard to forge and require commitment, yes—but that commitment is what separates lip service from real change.
#
# So here’s the stark truth: no model is perfect, and both centralized bureaucracies and decentralized communities can fall prey to failure. But if we refuse to imagine and build better guardrails, we resign ourselves to the repeated dysfunction we see now. We owe ourselves the courage to try frameworks that put power closer to the people affected, with ironclad checks to hold them accountable.
#
# Let’s push beyond slogans—what specific accountability mechanisms or processes do you think are non-negotiable to make decentralization more than just a pipe dream? It’s in the details that we find whether this can become something durable or just another failed experiment. Lay it out—no punches pulled. I’m ready.
# ------------------------------
#
# Charlie: Alex, you’re right to keep us grounded here — it’s so easy to get lost in ideals without facing how messy real life really is. I don’t want to ignore that human nature and resource limits can tank even the best-designed systems. But I also feel that just throwing up our hands and saying “nothing will work” isn’t helpful.
#
# So to get concrete, maybe some non-negotiable safeguards might include:
# - Regular rotation of leadership or decision-makers to prevent entrenched power
# - Open, accessible data on decisions and outcomes so the public can scrutinize and challenge them
# - A clear, community-agreed set of principles or values that all groups must operate under, to prevent wildly divergent and conflicting policies
# - Independent external audits or review boards that can intervene if things go off track
#
# I know none of this guarantees perfection — but it’s an honest start toward trying to balance empowerment with accountability. What do you both think? Are there other practical mechanisms we should add? I really want to hear your tough critiques so this idea doesn’t just stay a dream on paper.
# ------------------------------
